# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# the location of the file
recent_grads_file = "/Users/abdulsaboor/Documents/Programming_Languages/Python/Courses/DataQuest/files/recent-grads.csv"

# %%
# reading the csv file into a dataframe
recent_grads = pd.read_csv(recent_grads_file)

# %%
# the first row of the dataframe
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object

# %%
# the first few rows
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
# the last few rows
recent_grads.tail(3)
# Out:
#      Rank  Major_code                  Major   Total    Men   Women  \
# 170   171        5202    CLINICAL PSYCHOLOGY  2838.0  568.0  2270.0
# 171   172        5203  COUNSELING PSYCHOLOGY  4626.0  931.0  3695.0
# 172   173        3501        LIBRARY SCIENCE  1098.0  134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
# 172           0.104946   22000  20000  22000           288               338
#
#      Low_wage_jobs
# 170            622
# 171            308
# 172            192
#
# [3 rows x 21 columns]

# %%
# some of the common stats about the numerical columns of recent_grads
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
# dropping the rows with null values
recent_grads = recent_grads.dropna()

# it seems like there was only one row with null values.
recent_grads.count()
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %%
# Sample size and median
ax = recent_grads.plot(x="Sample_size", y="Median", kind="scatter")
ax.set_title("Sample_size vs Median")
# Out:
# Text(0.5,1,'Sample_size vs Median')

# %%
# sample size and Unemployment Rate
ax = recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter")
ax.set_title("Sample_size vs Unemployment_rate")
# Out:
# Text(0.5,1,'Sample_size vs Unemployment_rate')

# %%
# full time and median
ax = recent_grads.plot(x="Full_time", y="Median", kind="scatter")
ax.set_title("Full_time vs Median")
# Out:
# Text(0.5,1,'Full_time vs Median')

# %%
# sharewoman and unemployment rate
ax = recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter")
ax.set_title("ShareWomen vs Unemployment_rate")
# Out:
# Text(0.5,1,'ShareWomen vs Unemployment_rate?')

# %%
# men and median
ax = recent_grads.plot(x="Men", y="Median", kind="scatter")
ax.set_title("Men vs Median")
# Out:
# Text(0.5,1,'Men vs Median')

# %%
# women and median
ax = recent_grads.plot(x="Women", y="Median", kind="scatter")
ax.set_title("Women vs Median")
# Out:
# Text(0.5,1,'Women vs Median')

# %%
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
# so there were over 300,000 women who worked for less than 40,000 dollars per annum
recent_grads[recent_grads.Women == recent_grads.Women.max()]
# Out:
#      Rank  Major_code       Major     Total      Men     Women  \
# 145   146        5200  PSYCHOLOGY  393735.0  86648.0  307087.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 145  Psychology & Social Work    0.779933         2584    307933
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 145      ...           115172                174438       28169
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 145           0.083811   31500  24000  41000        125148            141860
#
#      Low_wage_jobs
# 145          48207
#
# [1 rows x 21 columns]

# %%
## just for fun 

for index in range(0,172):
    if recent_grads.iloc[index]['Total'] == recent_grads.iloc[index]['Men']+recent_grads.iloc[index]['Women']:
        print (True, "That")
# Out:
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That
# True That

# %%
# Out:
# /Users/abdulsaboor/Documents/Programming_Languages/Python/Tutorials
